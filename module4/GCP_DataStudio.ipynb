# %% [markdown]
# # Part 2 - GCP Data Studio
#
# ## <span style='background:yellow'> Please keep in mind that this is just part 1 of the module, and you have another half.
# Do not spend more than 5 hours on your GCP Exercise!</span>
# Come back to it later if you have more time or after the course is completed.
#
# ## Please Bookmark the help Center
# [Data Studio Help Center](https://support.google.com/datastudio/?hl=en#topic=6267740)
#
# From the help center:
#
# ## `What is GCP Data Studio?`
# >  GCP Data Studio is a real-time analytics and business intelligence (BI) dashboarding system that runs on Google Cloud Platform. Data Studio is a free tool that turns your data into informative, easy to read, easy to share, and fully customizable dashboards and reports. Data Studio can be used to:
# - Visualize your data through highly configurable charts and tables.
# - Easily connect to a variety of data sources.
# - Share your insights with your team or with the world.
# - Collaborate on reports with your team.
# - Speed up your report creation process with built-in sample reports.

# %% [markdown]
# ## Videos
#
# To get a little taste of Google Data Studio, please watch the first short video.
#  * Quick Introduction Video (5 minutes) https://youtu.be/6FTUpceqWnc
#
# If you feel you want more deep dives, I recommend watching these videos as your time permits.
#  * Google Data Studio Playlist with multiple quick How-To videos (Entire Playlist: 90 minutes):
#  https://youtube.com/playlist?list=PLI5YfMzCfRtag7tBfbVvA4_a6YZxWHEO4

# %% [markdown]
# ## Setup (Lab)
#
# Remember to access GCP through our special IAM portal.  See [GCP Getting Started](../module1/practices/GCP_Getting_Started.ipynb) for details.

# %% [markdown]
# The practices for this sub-module involve following some of the select tutorials from Google.
#
# For each practice, ensure your artifact is properly linked into this notebook in the appropriate location.
#
# ### Tutorial 1
#
# ##### Please Read all the Tutorial 1 instructions before you begin to avoid extra work or having to start over!
#
# ### [Create a Data Studio dashboard that queries a BigQuery table](https://cloud.google.com/bigquery/docs/bi-engine-data-studio)
#
# In this tutorial, you will:
#
# a) use the knowledge from module 3 to create a BigQuery dataset and table
#
# b) learn how to connect data studio to the BigQuery table
#
# c) create a simple data studio dashboard
#
#
# <span style='background:yellow'>You do not have to create any BI Engine reservation for this tutorial.</span>
#
# Therefore, you can **skip** the **Create your BI Engine reservation** section of the tutorial.
# That means your first GCP actions start at [Create a Dataset](https://cloud.google.com/bigquery/docs/bi-engine-data-studio#create_a_dataset).
#
#
# **Remember to use your SSO as a prefix for any resources you create, such as `scottgs_testdataset`**
#
#
# **Note** as the Console Interface is constantly evolving, you will have to extrapolate and interpolate some instructions using your technical intuition -- and maybe some Google -- to work through the activities.
#
#
#
# #### Estimated Tutorial Time: <span style='color:blue'>approximately 30 minutes</span>
#
#
#
# #### Artifacts Notes:
#
# - Download the report as a PDF Report and upload it into the `practices` folder. Rename it to `Practice1.pdf`
# ![PDF%20Download.png](attachment:PDF%20Download.png)
#
#
# - Click the Share button and select Manage Access tab. Make sure that Link sharing is On and **Anyone in umsystem.edu with the link can view** is selected from the drop down. Save the setting and Copy the link.
#
# ![Link%20Share.png](attachment:Link%20Share.png)

# %% [raw]
# # Add URL to Tutorial Dashboard below this line
#
# https://datastudio.google.com/reporting/a638d5ef-eb4a-4968-9201-0f8c0d15d9e9

# %% [markdown]
# ## Practices Tutorial
#
# ### Tutorial 2
# The practices for this sub-module involve following some of the select tutorials from the User Guide. We then ask you to do a few extra steps to practice your data science skills.
# ### [Create calculated fields in Data Studio](https://support.google.com/datastudio/answer/7569890?hl=en&ref_topic=9927030#zippy=%2Cin-this-article)
#
# In this tutorial, you will:
#
# - Learn how to create a simple arithmetic calculated field.
#
# - Create a conditional expression to evaluate your data and return different results.
#
# - Learn different approaches to implementing calculated fields.
#
#
# #### Practice Task and Artifact
#
# - Show the distribution of **Total** sale of each **Department** using a Pie-chart and Bar plot.
# - Download the pdf report and upload it into the `practices` folder. Rename it to `Practice2.pdf`.
#
# #### Estimated Tutorial Time: <span style='color:blue'>approximately 40 minutes</span>

# %% [raw]
# # Add URL to Tutorial Dashboard below this line
#
# https://datastudio.google.com/reporting/b419503f-81b0-42ab-863e-0a439dcf1b96

# %% [markdown]
# ## Excercises
# The exercises for this sub-module involve following some of the select tutorials from the User Guide. We then ask you to do a few extra steps to practice your data science skills.
# ### Tutorial 3
# ### [Solve a classic data blending use case](https://support.google.com/datastudio/answer/11828486)
# The tutorial uses the data in **[Google Sheets](https://docs.google.com/spreadsheets/d/1v74etUJflbLMfrfmlyAH2wFS99rcsVJrrRF6YmIAsW4/edit#gid=1315263233)**.
# This example answers the following questions you might have about the data:
#
# a) Which students took which classes, and what grade did each student receive in each class?
#
# b) What was the highest grade received in each class?
#
# c) Which student received the highest grade in each class?
#
#
# #### Artifact
#
# - Generate a table for each question and download the three tables as a signle pdf report and upload it into the `exercises` folder as `Exercise1.pdf`

# %% [raw]
# # Add URL to Eercise Dashboard URL below this line
#
# https://datastudio.google.com/reporting/db272c72-7e73-445b-aea9-88ada899c2b3

# %% [markdown]
# #### Exercise Task and Artifact
# - Add a field called `remark` to the table that was generated for `Question #a`:
#     - `remark` field has values based on the `grade` as follows:
#         - 90-100: Excellent
#         - 80-89: Very Good
#         - 70-79: Good
#         - 50-69: Fair
#         - 0-50: Poor
#
# - Download the pdf report and upload it into the exercises folder as Exercise2.pdf
#
# #### Estimated Tutorial Time: <span style='color:blue'>approximately 60-75 minutes</span>

# %% [raw]
# # Add URL to Eercise Dashboard URL below this line
#
# https://datastudio.google.com/reporting/db272c72-7e73-445b-aea9-88ada899c2b3

# %% [markdown]
# ## Submitting your work
#
# #### Steps:
#   1. Open Terminal in JupyterHub
#   1. Change into the course folder
#   1. Stage (Git Add) the module's learning activities
#   `git  add   module4`
#   1. Create your work snapshot (Git Commit)
#   `git   commit   -m   "Module 4 GCP Data Studio"`
#   1. Upload the snapshot to the server (Git Push)
#   `git   push`
